# %%
#Importing the libraries
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import calendar
from datetime import datetime
import yfinance as yf

# %%
#Create daily list
Mon = []
Tues = []
Wed = []
Thru = []
Fri = []
Sat = []
Sun = []

#create a function to get daily simple return for each day and append it to corres. date
def get_dsr(day, dsr):
    if day == 'Monday':
        Mon.append(float(dsr))
    elif day == 'Tuesday':
        Tues.append(float(dsr))
    elif day == 'Wednesday':
        Wed.append(float(dsr))
    elif day == 'Thrusday':
        Thru.append(float(dsr))
    elif day == 'Friday':
        Fri.append(float(dsr))
    elif day == 'Saturday':
        Sat.append(float(dsr))
    elif day == 'Sunday':
        Sun.append(float(dsr))
    else: 
        print('Something is wrong')

# %%
today = datetime.today().strftime('%Y-%m-%d')
today
# Out:
# '2022-12-29'

# %%
#Importing the data
df = yf.download('^CRSLDX', start= '2015-01-01', end= today)
#df = df.set_index(pd.DatetimeIndex(df['Date'].values))
#df = pd.read_csv('HDFCBANK.NS.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2015-01-01   6767.600098   6794.250000   6755.000000   6786.100098
# 2015-01-02   6792.399902   6883.049805   6792.399902   6866.450195
# 2015-01-05   6877.350098   6913.250000   6848.250000   6857.450195
# 2015-01-06   6817.649902   6817.649902   6646.399902   6656.799805
# 2015-01-07   6653.649902   6680.500000   6605.399902   6644.950195
# ...                  ...           ...           ...           ...
# 2022-12-21  15772.950195  15812.049805  15497.599609  15527.549805
# 2022-12-22  15599.549805  15636.099609  15369.599609  15431.500000
# 2022-12-23  15300.750000  15349.349609  15018.750000  15046.000000
# 2022-12-27  15375.200195  15433.650391  15278.599609  15418.349609
# 2022-12-28  15390.549805  15468.150391  15363.650391  15432.799805
#
#                Adj Close    Volume
# Date
# 2015-01-01   6786.100098   4409100
# 2015-01-02   6866.450195   6177400
# 2015-01-05   6857.450195   6143300
# ...

# %%
df.shape
# Out:
# (1970, 6)

# %%
#Calculate and show daily simple return
DSR = df['Close'].pct_change(1)#compute the dsr
df['DSR'] = DSR

df = df[0:]

# %%
df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2015-01-01   6767.600098   6794.250000   6755.000000   6786.100098
# 2015-01-02   6792.399902   6883.049805   6792.399902   6866.450195
# 2015-01-05   6877.350098   6913.250000   6848.250000   6857.450195
# 2015-01-06   6817.649902   6817.649902   6646.399902   6656.799805
# 2015-01-07   6653.649902   6680.500000   6605.399902   6644.950195
# ...                  ...           ...           ...           ...
# 2022-12-21  15772.950195  15812.049805  15497.599609  15527.549805
# 2022-12-22  15599.549805  15636.099609  15369.599609  15431.500000
# 2022-12-23  15300.750000  15349.349609  15018.750000  15046.000000
# 2022-12-27  15375.200195  15433.650391  15278.599609  15418.349609
# 2022-12-28  15390.549805  15468.150391  15363.650391  15432.799805
#
#                Adj Close    Volume       DSR
# Date
# 2015-01-01   6786.100098   4409100       NaN
# 2015-01-02   6866.450195   6177400  0.011840
# ...

# %%
#Create a loop to gather the daily simple returns of each day
for i in range(0, len(df)):
    df_date = str(df.index[i])#get current date & casting it as a string
    df_dsr = df['DSR'][i]#get current daily simple return
    df_month = df_date.split('-')[0]#get current month
    curr_date = df.index[i]#get the current date
    df_weekday = calendar.day_name[curr_date.weekday()]#get the weekday

    #Add the daily simple returns to the corresponding list for the day
    get_dsr(df_weekday, df_dsr)
# Out:
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# Something is wrong
# ...

# %%
#Create a function to average the returns of each weekday
def AVG(day):
    if not day:#if this true then list is empty so return a list containing 0
        return[0]
    else:
        return[sum(day)/len(day)]

# %%
#Create a df and set the index to be days of week
df_returns = pd.DataFrame(index=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
#Get the average for each weekday and add the values under column AVG
df_returns['AVG'] = AVG(Mon) + AVG(Tues) + AVG(Wed) + AVG(Thru) + AVG(Fri) + AVG(Sat) + AVG(Sun)

# %%
#Plot the AVG daily simple returns
df_returns.plot.bar()
# Out:
# <AxesSubplot:>

# %%
#Show the returns
df_returns
# Out:
#                 AVG
# Monday    -0.000862
# Tuesday    0.001565
# Wednesday  0.000683
# Thursday   0.000000
# Friday     0.000626
# Saturday   0.000000
# Sunday     0.000000
